# %%
import os
import zipfile

# Define the folder to be zipped
folder_path = '/content/own_data.zip'

# Define the name of the zip file
zip_filename = 'own_data.zip'

# Create the zip file
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, folder_path)
            zipf.write(file_path, arcname)

# %%
# Unzip the uploaded file
import zipfile

with zipfile.ZipFile('own_data.zip', 'r') as zip_ref:
    zip_ref.extractall('destination_folder')

# %%
# Define paths
zip_file_path = '/content/own_data.zip'  # Path to the uploaded zip file in Colab
extracted_dir_path = '/content/extracted/'  # Adjust the target directory in Colab

# Unzip the file
# !unzip -q "$zip_file_path" -d "$extracted_dir_path"

print("Extraction completed.")
# Out:
# warning [/content/own_data.zip]:  zipfile is empty
# Extraction completed.

# %%
import zipfile

# Define paths
zip_file_path = '/content/own_data.zip'  # Path to the uploaded zip file in Colab
extracted_dir_path = '/content/extracted/'  # Adjust the target directory in Colab

# Check if the zip file exists
if not os.path.exists(zip_file_path):
    print(f"Zip file not found: {zip_file_path}")
else:
    try:
        # Unzip the file
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extracted_dir_path)
            print("Extraction completed.")
    except Exception as e:
        print("An error occurred during extraction:")
        print(e)
# Out:
# Extraction completed.

# %%
import zipfile
import os

# Define paths
zip_file_path = '/content/own_data.zip'  # Path to the uploaded zip file in Colab
extracted_dir_path = '/content/extracted/'  # Adjust the target directory in Colab

# Check if the zip file exists
if not os.path.exists(zip_file_path):
    print(f"Zip file not found: {zip_file_path}")
else:
    try:
        # Create the target directory if it doesn't exist
        os.makedirs(extracted_dir_path, exist_ok=True)

        # Unzip the file
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extracted_dir_path)
            print("Extraction completed.")
    except Exception as e:
        print("An error occurred during extraction:")
        print(e)
# Out:
# Extraction completed.

# %%
# Define paths
zip_file_path = '/content/own_data.zip'  # Path to the uploaded zip file in Colab
extracted_dir_path = '/content/extracted/'  # Adjust the target directory in Colab

# Unzip the file
# !unzip -q "$zip_file_path" -d "$extracted_dir_path"

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.callbacks import ReduceLROnPlateau

# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=1, min_lr=0.00001)


# Define your classes
classes = ['angry', 'disgust', 'fear', 'happy', 'netural', 'sadness', 'surprise']

# Create your own CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(classes), activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Load and preprocess images from train and test folders
data = []
labels = []

for emotion_class in classes:
    for folder in ['/content/extracted/own_data/train', '/content/extracted/own_data/test']:
        class_path = os.path.join(folder, emotion_class)
        for image_file in os.listdir(class_path):
            image_path = os.path.join(class_path, image_file)
            img = tf.keras.preprocessing.image.load_img(image_path, target_size=(48, 48))
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            data.append(img_array)
            labels.append(classes.index(emotion_class))

data = np.array(data)
labels = np.array(labels)

# One-hot encode the labels
labels_one_hot = to_categorical(labels, num_classes=len(classes))

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels_one_hot, test_size=0.2, random_state=42)

# Train your own CNN model
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.2)

# Extract features using your own CNN model
X_train_features = model.predict(X_train)
X_test_features = model.predict(X_test)

# Flatten the extracted features
X_train_flatten = X_train_features.reshape(X_train_features.shape[0], -1)
X_test_flatten = X_test_features.reshape(X_test_features.shape[0], -1)

# Convert one-hot encoded labels back to integer labels
y_train_integer = np.argmax(y_train, axis=1)
y_test_integer = np.argmax(y_test, axis=1)

# Train an SVM classifier on the extracted features
svm_classifier = SVC(kernel='linear', C=1.0)
svm_classifier.fit(X_train_flatten, y_train_integer)

# Make predictions on the test set
predictions = svm_classifier.predict(X_test_flatten)

# Calculate accuracy
accuracy = accuracy_score(y_test_integer, predictions)
# print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 2s 18ms/step - loss: 11.8991 - accuracy: 0.1536 - val_loss: 1.9469 - val_accuracy: 0.1418
# Epoch 2/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9651 - accuracy: 0.1704 - val_loss: 1.9340 - val_accuracy: 0.2239
# Epoch 3/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9345 - accuracy: 0.1685 - val_loss: 1.9233 - val_accuracy: 0.2015
# Epoch 4/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9134 - accuracy: 0.2041 - val_loss: 1.9028 - val_accuracy: 0.2015
# Epoch 5/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9039 - accuracy: 0.1742 - val_loss: 1.9009 - val_accuracy: 0.2239
# Epoch 6/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8844 - accuracy: 0.1854 - val_loss: 1.9097 - val_accuracy: 0.2090
# Epoch 7/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.8354 - accuracy: 0.2566 - val_loss: 1.8720 - val_accuracy: 0.1866
# Epoch 8/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8039 - accuracy: 0.2453 - val_loss: 1.8725 - val_accuracy: 0.2612
# Epoch 9/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.7640 - accuracy: 0.2921 - val_loss: 1.8404 - val_accuracy: 0.1940
# Epoch 10/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7042 - accuracy: 0.2790 - val_loss: 1.7732 - val_accuracy: 0.2687
# Epoch 11/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6648 - accuracy: 0.3221 - val_loss: 1.8361 - val_accuracy: 0.2463
# Epoch 12/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6243 - accuracy: 0.3390 - val_loss: 1.7867 - val_accuracy: 0.2612
# Epoch 13/100
# 17/17 [==============================] - 0s 8ms/step - loss: 1.5520 - accuracy: 0.3820 - val_loss: 1.7410 - val_accuracy: 0.3209
# Epoch 14/100
100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4232 - accuracy: 0.8090 - val_loss: 1.5686 - val_accuracy: 0.5821
# Epoch 40/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3523 - accuracy: 0.8596 - val_loss: 1.5811 - val_accuracy: 0.5896
# Epoch 41/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3914 - accuracy: 0.8502 - val_loss: 1.6722 - val_accuracy: 0.6119
# Epoch 42/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3002 - accuracy: 0.8989 - val_loss: 1.6495 - val_accuracy: 0.5821
# Epoch 43/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3431 - accuracy: 0.8558 - val_loss: 1.6287 - val_accuracy: 0.6269
# Epoch 44/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3662 - accuracy: 0.8371 - val_loss: 1.5280 - val_accuracy: 0.6194
# Epoch 45/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3197 - accuracy: 0.8727 - val_loss: 1.4474 - val_accuracy: 0.6343
# Epoch 46/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2786 - accuracy: 0.8989 - val_loss: 1.7890 - val_accuracy: 0.6493
# Epoch 47/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2846 - accuracy: 0.8801 - val_loss: 1.5401 - val_accuracy: 0.6418
# Epoch 48/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3226 - accuracy: 0.8745 - val_loss: 1.4903 - val_accuracy: 0.6194
# Epoch 49/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3291 - accuracy: 0.8633 - val_loss: 1.5094 - val_accuracy: 0.6269
# Epoch 50/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2619 - accuracy: 0.8989 - val_loss: 1.4563 - val_accuracy: 0.6119
# Epoch 51/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2545 - accuracy: 0.9045 - val_loss: 1.6721 - val_accuracy: 0.6119
# Epoch 52/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2456 - accuracy: 0.9045 - val_loss: 1.7017 - val_accuracy: 0.6194
# Epoch 53/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2671 - accuracy: 0.9045 - val_loss: 1.6646 - val_accuracy: 0.5970
# Epoch 54/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2359 - accuracy: 0.8951 - val_loss: 1.8348 - val_accuracy: 0.6194
# Epoch 55/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2943 - accuracy: 0.8820 - val_loss: 1.8420 - val_accuracy: 0.5672
# Epoch 56/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2654 - accuracy: 0.9064 - val_loss: 1.5519 - val_accuracy: 0.6493
# Epoch 57/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2754 - accuracy: 0.8914 - val_loss: 1.5765 - val_accuracy: 0.6045
# Epoch 58/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2176 - accuracy: 0.9195 - val_loss: 1.7140 - val_accuracy: 0.6343
# Epoch 59/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2257 - accuracy: 0.9007 - val_loss: 1.6114 - val_accuracy: 0.6642
# Epoch 60/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1985 - accuracy: 0.9251 - val_loss: 1.5800 - val_accuracy: 0.6418
# Epoch 61/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2309 - accuracy: 0.9026 - val_loss: 1.8121 - val_accuracy: 0.6642
# Epoch 62/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2514 - accuracy: 0.9120 - val_loss: 1.8262 - val_accuracy: 0.6194
# Epoch 63/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2273 - accuracy: 0.9120 - val_loss: 1.7085 - val_accuracy: 0.6493
# Epoch 64/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2032 - accuracy: 0.9270 - val_loss: 1.8689 - val_accuracy: 0.6194
# Epoch 65/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1834 - accuracy: 0.9345 - val_loss: 1.9661 - val_accuracy: 0.6119
# Epoch 66/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1710 - accuracy: 0.9270 - val_loss: 1.8526 - val_accuracy: 0.6119
# Epoch 67/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.
100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1462 - accuracy: 0.9476 - val_loss: 1.9265 - val_accuracy: 0.6567
# Epoch 97/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1008 - accuracy: 0.9682 - val_loss: 2.4653 - val_accuracy: 0.6194
# Epoch 98/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0656 - accuracy: 0.9719 - val_loss: 2.2374 - val_accuracy: 0.6269
# Epoch 99/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0843 - accuracy: 0.9663 - val_loss: 2.4743 - val_accuracy: 0.6269
# Epoch 100/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0787 - accuracy: 0.9663 - val_loss: 2.3712 - val_accuracy: 0.6418
# 21/21 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate confusion matrix
confusion_mat = confusion_matrix(y_test_integer, predictions)
print("Confusion Matrix:\n", confusion_mat)

# Calculate classification report
class_report = classification_report(y_test_integer, predictions, target_names=classes)
print("Classification Report:\n", class_report)

# Calculate overall accuracy
overall_accuracy = accuracy_score(y_test_integer, predictions)
print("Overall Accuracy:", overall_accuracy)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
#  [[21  2  0  1  6  2  0]
#  [ 2 11  2  2  0  0  0]
#  [ 1  1 13  1  3  0  1]
#  [ 0  2  4  9  0  1  3]
#  [ 2  0  6  0 12  1  2]
#  [ 8  0  0  0  2 19  0]
#  [ 2  1  1  0  2  2 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.58      0.66      0.62        32
#      disgust       0.65      0.65      0.65        17
#         fear       0.50      0.65      0.57        20
#        happy       0.69      0.47      0.56        19
#      netural       0.48      0.52      0.50        23
#      sadness       0.76      0.66      0.70        29
#     surprise       0.77      0.71      0.74        28
#
#     accuracy                           0.62       168
#    macro avg       0.63      0.62      0.62       168
# weighted avg       0.64      0.62      0.63       168
#
# Overall Accuracy: 0.625

# %%
# Create a histogram of predicted classes
plt.figure(figsize=(8, 6))
plt.hist(predictions, bins=len(classes), alpha=0.7, color='blue', edgecolor='black')
plt.xticks(range(len(classes)), classes, rotation='vertical')
plt.xlabel("Predicted Classes")
plt.ylabel("Frequency")
plt.title("Predicted Class Distribution")
plt.show()

# %%
# ... Your existing code ...

# Calculate classification report
class_report = classification_report(y_test_integer, predictions, target_names=classes, output_dict=True)
print("Classification Report:\n", class_report)

# Convert classification report dictionary to a DataFrame for easier manipulation
import pandas as pd
report_df = pd.DataFrame(class_report).transpose()

# Visualize precision, recall, F1-score for each class
plt.figure(figsize=(10, 6))
report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(10, 6))
plt.title('Precision, Recall, and F1-Score for Each Class')
plt.xlabel('Emotion Classes')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# Visualize support for each class
plt.figure(figsize=(8, 6))
sns.barplot(x=report_df.index, y=report_df['support'], palette='Blues')
plt.title('Support for Each Class')
plt.xlabel('Emotion Classes')
plt.ylabel('Support')
plt.xticks(rotation=45)
plt.show()
# Out:
# Classification Report:
#  {'angry': {'precision': 0.7037037037037037, 'recall': 0.59375, 'f1-score': 0.6440677966101694, 'support': 32}, 'disgust': {'precision': 0.6111111111111112, 'recall': 0.6470588235294118, 'f1-score': 0.6285714285714287, 'support': 17}, 'fear': {'precision': 0.46875, 'recall': 0.75, 'f1-score': 0.5769230769230769, 'support': 20}, 'happy': {'precision': 0.6363636363636364, 'recall': 0.3684210526315789, 'f1-score': 0.4666666666666667, 'support': 19}, 'netural': {'precision': 0.5714285714285714, 'recall': 0.5217391304347826, 'f1-score': 0.5454545454545454, 'support': 23}, 'sadness': {'precision': 0.6428571428571429, 'recall': 0.6206896551724138, 'f1-score': 0.6315789473684211, 'support': 29}, 'surprise': {'precision': 0.6451612903225806, 'recall': 0.7142857142857143, 'f1-score': 0.6779661016949152, 'support': 28}, 'accuracy': 0.6071428571428571, 'macro avg': {'precision': 0.611339350826678, 'recall': 0.6022777680077002, 'f1-score': 0.5958897947556033, 'support': 168}, 'weighted avg': {'precision': 0.6203782554348991, 'recall': 0.6071428571428571, 'f1-score': 0.604436350291454, 'support': 168}}

# %%
import matplotlib.pyplot as plt

# Load and preprocess a single image for prediction
def preprocess_image(image_path, model):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(48, 48))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize pixel values
    intermediate_output = model.predict(img_array)
    intermediate_output_flatten = intermediate_output.reshape(intermediate_output.shape[0], -1)
    return img_array, intermediate_output_flatten

# Path to the test image you want to predict on
test_image_path = "/content/angry_0_4096.jpg"

# Preprocess the test image and get the image array
test_image, test_features = preprocess_image(test_image_path, model)

# Get decision function distances for each class using the SVM classifier
decision_distances = svm_classifier.decision_function(test_features)

# Convert decision distances to prediction scores
prediction_scores = decision_distances[0]  # Assuming you have a single image

# Create a dictionary to associate each class with its prediction score
class_scores = {emotion_class: score for emotion_class, score in zip(classes, prediction_scores)}

# Determine the predicted emotion based on the class with the highest score
predicted_emotion = max(class_scores, key=class_scores.get)

# Plot the image and overlay the predicted emotion labels with scores
plt.imshow(test_image[0])
plt.title("Predicted Emotion: " + predicted_emotion)
plt.axis('off')

# Display the predicted scores for each class on the image
for emotion_class, score in class_scores.items():
    plt.text(10, 10 + 20 * classes.index(emotion_class), f"{emotion_class}: {score:.2f}", color='red')

plt.show()
# Out:
# 1/1 [==============================] - 0s 124ms/step

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# Define your classes
classes = ['angry', 'disgust', 'fear', 'happy', 'netural', 'sadness', 'surprise']

# Load and preprocess a single image for visualization
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(48, 48))
    img_array = img_to_array(img)
    return img_array

# Path to the directory containing images for each class
base_dir = '/content/extracted/own_data/train'

# Create a new figure and specify the number of rows and columns for subplots
fig, axes = plt.subplots(1, len(classes), figsize=(15, 5))

# Iterate through each class and display an image
for idx, emotion_class in enumerate(classes):
    class_path = os.path.join(base_dir, emotion_class)
    image_files = os.listdir(class_path)
    image_path = os.path.join(class_path, image_files[0])  # Take the first image in the class folder
    image_array = preprocess_image(image_path)

    # Display the image
    axes[idx].imshow(image_array.astype(np.uint8))
    axes[idx].set_title(emotion_class)
    axes[idx].axis('off')

plt.tight_layout()
plt.show()
